# %% [markdown]
# <h2>Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation.The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# Explore and analyze the data to discover key factors responsible for customer churn
# and come up with ways/recommendations to ensure customer retention.<h2>

# %% [markdown]
# <h3> Let us import the liabreries and .csv file into Notebook, after that let us perform basic operations such as info and describe <h3>

# %%
import numpy as np
import pandas as pd
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Deba\\Downloads\\Telecom_Churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
list[df['State'].unique()]
# Out:
# list[array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)]

# %%
state_total_day_minutes = df[['Total day minutes','State']]

# %%
state_total_day_minutes
# Out:
#       Total day minutes State
# 0                 265.1    KS
# 1                 161.6    OH
# 2                 243.4    NJ
# 3                 299.4    OH
# 4                 166.7    OK
# ...                 ...   ...
# 3328              156.2    AZ
# 3329              231.1    WV
# 3330              180.8    RI
# 3331              213.8    CT
# 3332              234.4    TN
#
# [3333 rows x 2 columns]

# %% [markdown]
# <h3> Q 1 Bar plot <h3>

# %%
state_total_day_minutes.plot(kind='bar')

plt.title('Total minutes and states')
plt.ylabel('Number of minutes')
plt.xlabel('states')
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# <h3>Q 2 multi line plot<h3>

# %%
unique_states = df[['State','Total day minutes','Total eve minutes','Total night minutes','Total intl minutes']]

# %%
print(unique_states)
# Out:
#      State  Total day minutes  Total eve minutes  Total night minutes  \
# 0       KS              265.1              197.4                244.7
# 1       OH              161.6              195.5                254.4
# 2       NJ              243.4              121.2                162.6
# 3       OH              299.4               61.9                196.9
# 4       OK              166.7              148.3                186.9
# ...    ...                ...                ...                  ...
# 3328    AZ              156.2              215.5                279.1
# 3329    WV              231.1              153.4                191.3
# 3330    RI              180.8              288.8                191.9
# 3331    CT              213.8              159.6                139.2
# 3332    TN              234.4              265.9                241.4
#
#       Total intl minutes
# 0                   10.0
# 1                   13.7
# 2                   12.2
# ...

# %%
unique_states.plot()

plt.title('Total minutes and states')
plt.ylabel('Number of minutes')
plt.xlabel('states')
# Out:
# Text(0.5, 0, 'states')

# %% [markdown]
# <h3> Q 6 Bar plot <h3>

# %%
 voice_mail_plan_state = df[['State','Voice mail plan']]

# %%
print(voice_mail_plan_state)
# Out:
#      State Voice mail plan
# 0       KS             Yes
# 1       OH             Yes
# 2       NJ              No
# 3       OH              No
# 4       OK              No
# ...    ...             ...
# 3328    AZ             Yes
# 3329    WV              No
# 3330    RI              No
# 3331    CT              No
# 3332    TN             Yes
#
# [3333 rows x 2 columns]

# %%
voice_mail_plan_state.plot(kind='bar')

plt.title('More voice call plan states')
plt.ylabel('Number of minutes')
plt.xlabel('states')
plt.rcParams['figure.figsize'] = (10, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7644/2013399291.py in <module>
# ----> 1 voice_mail_plan_state.plot(kind='bar')
#       2
#       3 plt.title('More voice call plan states')
#       4 plt.ylabel('Number of minutes')
#       5 plt.xlabel('states')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...
